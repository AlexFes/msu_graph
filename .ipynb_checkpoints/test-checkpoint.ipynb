# %%
from igraph import *
import cairo

# %%
g = Graph.GRG(10, 0.5)
print(g.summary())
# Out:
# IGRAPH U--- 10 21 --
# + attr: x (v), y (v)

# %%
g = Graph.Tree(10, 3)
print(g.summary())

# %%
g.vs["color"] = "green"
for ind, val in enumerate(g.vs):
    g.vs[ind]["label"] = ind

layout = g.layout("kk")

# %%
plot(g, layout = layout, bbox = (300, 300), margin = 20)

# %%
g.get_adjacency().shape
print(list(map(lambda x: x.degree(), g.vs)))
# Out:
# [2, 7, 7, 8, 7, 8, 6, 3, 6, 6]

# %% [markdown]
# ### Get 1-net for graph

# %%
print(list(map(lambda x: x.degree(), g.vs)))

# %%
g.vs[0].attributes()
# Out:
# {'x': 0.060991200494182496,
#  'y': 0.38177086937275684,
#  'color': 'green',
#  'label': 0}
